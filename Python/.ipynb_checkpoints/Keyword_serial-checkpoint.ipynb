# %% [markdown]
# # Entire Serial Implementation with Wordlist

# %%
import sys
import time

def keyword_picker():
    print("Enter the Key")
    keyword = input("Enter key: ").upper()
    for i in range(len(keyword)):
        pos = i
        for j in range(len(keyword)):
            if pos == j:
                continue
            elif keyword[i] == keyword[j]:
                print("Letter {} repeating in keyword".format(keyword[i]))
                sys.exit()
    temp = ""
    for i in range(len(keyword)):
        temp += keyword[i]
    for i in range(26):
        temp += chr(i+65)

    alpha_with_key = ""
    for i in range(len(temp)):
        found = False
        for j in range(len(alpha_with_key)):
            if temp[i] == alpha_with_key[j]:
                found = True
                break
        if not found:
            alpha_with_key += temp[i]
    return alpha_with_key


def encryption(alpha_key, alpha,word):
    message = word.upper()

    encrypted_text = ""
    for i in range(len(message)):
        if message[i] == chr(32):
            encrypted_text += " "
        else:
            counter = 0
            for j in range(len(alpha)):
                if message[i] == alpha[j]:
                    encrypted_text += alpha_key[counter]
                    break
                else:
                    counter += 1
    #print("Encrypted Message: {}".format(encrypted_text))


def decryption(alpha_key, alpha,word):
    
    message = word.upper()

    decrypted_text = ""
    for i in range(len(message)):
        if message[i] == chr(32):
            decrypted_text += " "
        else:
            counter = 0
            for j in range(len(alpha)):
                if message[i] == alpha_key[j]:
                    decrypted_text += alpha[counter]
                    break
                else:
                    counter += 1
    #print("Decrypted Text: {}".format(decrypted_text))


def main():     
                
    alpha = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    alpha_key = keyword_picker()

    choice = int(input("1. Encryption\n2. Decryption\nChoose(1,2): "))
    
    if choice == 1:
        start_time = time.time()
        print("---Encrypting---")
        with open('dataset.txt','r') as file:
            enc=[encryption(alpha_key,alpha,word) for word in file.read().split()]
        end_time=time.time()
        print("Total number of words= ",len(enc))
        print("Execution time= ",end_time-start_time)

    elif choice == 2:
        start_time = time.time()
        print("---Decrypting---")
        with open('dataset.txt','r') as file:
            dec=[encryption(alpha_key,alpha,word) for word in file.read().split()]
        end_time=time.time()
        print("Total number of words= ",len(dec))
        print("Execution time= ",end_time-start_time)
    else:
        print("Incorrect Choice")

if __name__ == "__main__":
    main()
# Out:
# Enter the Key
# Enter key: keywords
# 1. Encryption
# 2. Decryption
# Choose(1,2): 1
# ---Encrypting---
# Total number of words=  12035182
# Execution time=  154.5881016254425

# %% [markdown]
# # Dask Dataframe Implementation

# %%
import sys
import time
import joblib
import dask.dataframe as dd
from joblib import Parallel, delayed

def keyword_picker():
    print("Enter the Key")
    keyword = input("Enter key: ").upper()
    for i in range(len(keyword)):
        pos = i
        for j in range(len(keyword)):
            if pos == j:
                continue
            elif keyword[i] == keyword[j]:
                print("Letter {} repeating in keyword".format(keyword[i]))
                sys.exit()
    temp = ""
    for i in range(len(keyword)):
        temp += keyword[i]
    for i in range(26):
        temp += chr(i+65)

    alpha_with_key = ""
    for i in range(len(temp)):
        found = False
        for j in range(len(alpha_with_key)):
            if temp[i] == alpha_with_key[j]:
                found = True
                break
        if not found:
            alpha_with_key += temp[i]
    return alpha_with_key


def encryption(alpha_key, alpha,word):
    message = word.upper()

    encrypted_text = ""
    for i in range(len(message)):
        if message[i] == chr(32):
            encrypted_text += " "
        else:
            counter = 0
            for j in range(len(alpha)):
                if message[i] == alpha[j]:
                    encrypted_text += alpha_key[counter]
                    break
                else:
                    counter += 1
    return encrypted_text


def decryption(alpha_key, alpha,word):
    
    message = word.upper()

    decrypted_text = ""
    for i in range(len(message)):
        if message[i] == chr(32):
            decrypted_text += " "
        else:
            counter = 0
            for j in range(len(alpha)):
                if message[i] == alpha_key[j]:
                    decrypted_text += alpha[counter]
                    break
                else:
                    counter += 1
    return decrypted_text


def main():     
                
    alpha = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    alpha_key = keyword_picker()

    choice = int(input("1. Encryption\n2. Decryption\nChoose(1,2): "))
    
    if choice == 1:
        words=dd.read_csv('dataset.txt').repartition(npartitions=8)
        start_time = time.time()
        print("---Encrypting---")
        words=words.apply(lambda x: encryption(alpha_key,alpha,str(x)),meta=('str'),axis=1).compute()
        end_time=time.time()
        print("Execution time= ",end_time-start_time)

    elif choice == 2:
        words=dd.read_csv('dataset.txt').repartition(npartitions=8)
        start_time = time.time()
        print("---Decrypting---")
        words=words.apply(lambda x: decryption(alpha_key,alpha,str(x)),meta=('str'),axis=1).compute()
        end_time=time.time()
        print("Execution time= ",end_time-start_time)
    else:
        print("Incorrect Choice")

if __name__ == "__main__":
    main()
# Out:
# Enter the Key
# Enter key: keywords
# 1. Encryption
# 2. Decryption
# Choose(1,2): 1
# ---Encrypting---

# %% [markdown]
# # Joblib

# %%
import sys
import time
import joblib
import dask.dataframe as dd
from joblib import Parallel, delayed

def keyword_picker():
    print("Enter the Key")
    keyword = input("Enter key: ").upper()
    for i in range(len(keyword)):
        pos = i
        for j in range(len(keyword)):
            if pos == j:
                continue
            elif keyword[i] == keyword[j]:
                print("Letter {} repeating in keyword".format(keyword[i]))
                sys.exit()
    temp = ""
    for i in range(len(keyword)):
        temp += keyword[i]
    for i in range(26):
        temp += chr(i+65)

    alpha_with_key = ""
    for i in range(len(temp)):
        found = False
        for j in range(len(alpha_with_key)):
            if temp[i] == alpha_with_key[j]:
                found = True
                break
        if not found:
            alpha_with_key += temp[i]
    return alpha_with_key


def encryption(alpha_key, alpha,word):
    message = word.upper()

    encrypted_text = ""
    for i in range(len(message)):
        if message[i] == chr(32):
            encrypted_text += " "
        else:
            counter = 0
            for j in range(len(alpha)):
                if message[i] == alpha[j]:
                    encrypted_text += alpha_key[counter]
                    break
                else:
                    counter += 1
    return encrypted_text


def decryption(alpha_key, alpha,word):
    
    message = word.upper()

    decrypted_text = ""
    for i in range(len(message)):
        if message[i] == chr(32):
            decrypted_text += " "
        else:
            counter = 0
            for j in range(len(alpha)):
                if message[i] == alpha_key[j]:
                    decrypted_text += alpha[counter]
                    break
                else:
                    counter += 1
    return decrypted_text


def main():     
                
    alpha = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    alpha_key = keyword_picker()

    choice = int(input("1. Encryption\n2. Decryption\nChoose(1,2): "))
    
    if choice == 1:
        words=dd.read_csv('dataset.txt').repartition(npartitions=8)
        start_time = time.time()
        print("---Encrypting---")
        with open('dataset.txt','r') as file:
            Parallel(8,verbose=50)(delayed(encryption)(alpha_key,alpha,word) for word in file.read().split())
        end_time=time.time()
        print("Execution time= ",end_time-start_time)

    elif choice == 2:
        words=dd.read_csv('dataset.txt').repartition(npartitions=8)
        start_time = time.time()
        print("---Decrypting---")
        words=words.apply(lambda x: decryption(alpha_key,alpha,str(x)),meta=('str'),axis=1).compute()
        end_time=time.time()
        print("Execution time= ",end_time-start_time)
    else:
        print("Incorrect Choice")

if __name__ == "__main__":
    main()

# %%
from joblib import Parallel, delayed
alpha = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
alpha_key = keyword_picker()
with open('untitled.txt','r') as file:
    x=Parallel(8,verbose=50)(delayed(encryption)(alpha_key,alpha,word) for word in file.read().split())
# Out:
# Enter the Key
# Enter key: keywords
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Batch computation too fast (0.0050s.) Setting batch_size=2.
# [Parallel(n_jobs=8)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done   3 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done   4 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done   5 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done   6 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done   7 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done   9 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  11 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  13 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  14 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  15 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  16 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Batch computation too fast (0.0157s.) Setting batch_size=4.
# [Parallel(n_jobs=8)]: Done  20 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  22 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  24 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  28 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  30 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  32 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  36 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  40 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  44 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  46 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  48 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Batch computation too fast (0.0181s.) Setting batch_size=8.
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  60 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  64 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  68 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  72 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  76 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  80 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  81 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  82 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  83 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  84 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  86 out of  99 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done  88 out of  99 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done  90 out of  99 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done  92 out of  99 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done  94 out of  99 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done  96 out of  99 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done  99 out of  99 | elapsed:    0.0s finished
